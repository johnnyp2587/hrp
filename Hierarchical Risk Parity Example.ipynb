# %%
import scipy.cluster.hierarchy as sch
import numpy as np
import pandas as pd
from datetime import date
from matplotlib import pyplot as plt
import cvxopt as opt # optimization library
from cvxopt import blas, solvers
from alpha_vantage.timeseries import TimeSeries # free stock data api
import ffn # financial functions
# import config
# Out:
# /usr/local/lib/python3.7/site-packages/ffn/core.py:27: MatplotlibDeprecationWarning: The 'warn' parameter of use() is deprecated since Matplotlib 3.1 and will be removed in 3.3.  If any parameter follows 'warn', they should be pass as keyword, not positionally.
#   matplotlib.use('agg', warn=False)
# /usr/local/lib/python3.7/site-packages/pandas_datareader/compat/__init__.py:7: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   from pandas.util.testing import assert_frame_equal

# %% [markdown]
# ## Define Hierarchical Risk Parity functions

# %%
# compute the inverse-variance portfolio
def getIVP(cov, **kargs):
    ivp = 1. / np.diag(cov)
    ivp /= ivp.sum()
    return ivp

# %%
# compute variance per cluster
def getClusterVar(cov,cItems):
    cov_ = cov.loc[cItems,cItems] # matrix slice
    w_ = getIVP(cov_).reshape(-1,1)
    cVar = np.dot(np.dot(w_.T,cov_),w_)[0,0]
    return cVar

# %%
# sort clusters by distance
def getQuasiDiag(link):
    link = link.astype(int)
    sortIx = pd.Series([link[-1, 0], link[-1, 1]])
    numItems = link[-1, 3]  # number of original items
    while sortIx.max() >= numItems:
        sortIx.index = range(0, sortIx.shape[0] * 2, 2)  # make space
        df0 = sortIx[sortIx >= numItems]  # find clusters
        i = df0.index
        j = df0.values - numItems
        sortIx[i] = link[j, 0]  # item 1
        df0 = pd.Series(link[j, 1], index=i + 1)
        sortIx = sortIx.append(df0)  # item 2
        sortIx = sortIx.sort_index()  # re-sort
        sortIx.index = range(sortIx.shape[0])  # re-index
    return sortIx.tolist()

# %%
# compute HRP allocation
def getRecBipart(cov, sortIx):
    w = pd.Series(1, index=sortIx)
    cItems = [sortIx]  # initialize all items in one cluster
    while len(cItems) > 0:
        cItems = [i[j:k] for i in cItems for j, k in ((0, len(i) // 2), (len(i) // 2, len(i))) if len(i) > 1]  # bi-section
        for i in range(0, len(cItems), 2):  # parse in pairs
            cItems0 = cItems[i]  # cluster 1
            cItems1 = cItems[i + 1]  # cluster 2
            cVar0 = getClusterVar(cov, cItems0)
            cVar1 = getClusterVar(cov, cItems1)
            alpha = 1 - cVar0 / (cVar0 + cVar1)
            w[cItems0] *= alpha  # weight 1
            w[cItems1] *= 1 - alpha  # weight 2
    return w

# %%
# define distance measure based on correlation, where 0<=d[i,j]<=1
def correlDist(corr):
    dist = ((1 - corr) / 2.)**.5  # distance matrix
    return dist

# %%
# construct hierarchical portfolio
def getHRP(cov, corr):
    dist = correlDist(corr)
    link = sch.linkage(dist, 'single')
    #dn = sch.dendrogram(link, labels=cov.index.values, label_rotation=90)
    #plt.show()
    sortIx = getQuasiDiag(link)
    sortIx = corr.index[sortIx].tolist()
    hrp = getRecBipart(cov, sortIx)
    return hrp.sort_index()

# %% [markdown]
# ## Define Markowitz Portfolio functions, for comparison

# %%
def getMVP(cov):

    cov = cov.T.values
    n = len(cov)
    N = 100
    mus = [10 ** (5.0 * t / N - 1.0) for t in range(N)]

    # convert to cvxopt matrices
    S = opt.matrix(cov)
    pbar = opt.matrix(np.ones(cov.shape[0]))

    # create constraint matrices
    G = -opt.matrix(np.eye(n))  # negative n x n identity matrix
    h = opt.matrix(0.0, (n, 1))
    A = opt.matrix(1.0, (1, n))
    b = opt.matrix(1.0)

    # use quadratic programming to calculate efficient frontier weights
    portfolios = [solvers.qp(mu * S, -pbar, G, h, A, b)['x'] for mu in mus]
    # calculate risks and returns for the frontier
    returns = [blas.dot(pbar, x) for x in portfolios] # note that we need a returns "forecast"!
    risks = [np.sqrt(blas.dot(x, S * x)) for x in portfolios]
    # calculate 2nd degree polynomial of the frontier curve
    m1 = np.polyfit(returns, risks, 2)
    x1 = np.sqrt(m1[2] / m1[0])
    # Ccalculate the optimal portfolio
    wt = solvers.qp(opt.matrix(x1 * S), -pbar, G, h, A, b)['x']

    return list(wt)

# %% [markdown]
# ## Compare approaches

# %%
# first, define a function to compare across all portfolio construction approaches
def get_all_portfolios(returns):
    
    cov, corr = returns.cov(), returns.corr()
    hrp = getHRP(cov, corr)
    ivp = getIVP(cov)
    ivp = pd.Series(ivp, index=cov.index)
    mvp = getMVP(cov)
    mvp = pd.Series(mvp, index=cov.index)
    
    portfolios = pd.DataFrame([mvp, ivp, hrp], index=['MVP', 'IVP', 'HRP']).T
    
    return portfolios

# %%
# define stock universe
stocks = {
    "Apple": "AAPL",
    "Amazon": "AMZN",
    "Alphabet": "GOOG",
    "Microsoft": "MSFT",
    "Facebook": "FB",
    #"Alibaba": "BABA",
    #"Berkshire Hathaway": "BRK-A",
    #"Tencent": "TCEHY",
    #"JPMorgan": "JPM",
    #"ExxonMobil": "XOM",
    #"Johnson & Johnson": "JNJ",
    #"Samsung Electronics": "005930.KS",
    #"Bank of America": "BAC"
}

# %%
# get stock data
stocks = pd.DataFrame(list(stocks.items()), columns=['name', 'symbol'])
ts = TimeSeries(key = '######', output_format = 'pandas') # note this is where need to put Alpha Vantage API key
stocks_close = pd.DataFrame()

for symbol in stocks.symbol.values:
    data, _ = ts.get_daily(symbol=symbol, outputsize='full')
    close = data['4. close']
    close.index = pd.to_datetime(close.index)
    stocks_close = stocks_close.append(close)

stocks_close = stocks_close.T
stocks_close = stocks_close.sort_index()
stocks_close = stocks_close.fillna(method='ffill')
stocks_close.columns = stocks.name.values
stocks_close = stocks_close["2015-01-01":"2020-03-31"]
returns = stocks_close.to_returns().dropna()

# %%
returns.head(5)
# Out:
#                Apple    Amazon  Alphabet  Microsoft  Facebook
# 2015-01-05 -0.028172 -0.020517 -0.020846  -0.009303 -0.016061
# 2015-01-06  0.000094 -0.022833 -0.023177  -0.014571 -0.013473
# 2015-01-07  0.014022  0.010600 -0.001713   0.012705  0.000000
# 2015-01-08  0.038422  0.006836  0.003153   0.029418  0.026592
# 2015-01-09  0.001072 -0.011749 -0.012951  -0.008405 -0.005564

# %%
# compute portfolios
portfolios = get_all_portfolios(returns)
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:4: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   after removing the cwd from sys.path.
#      pcost       dcost       gap    pres   dres
#  0: -9.9999e-01 -2.0000e+00  1e+00  1e-16  1e+00
#  1: -9.9999e-01 -1.0100e+00  1e-02  6e-17  1e-02
#  2: -9.9999e-01 -1.0001e+00  1e-04  7e-17  1e-04
#  3: -9.9999e-01 -9.9999e-01  2e-06  7e-17  2e-06
#  4: -9.9999e-01 -9.9999e-01  2e-07  1e-16  1e-07
#  5: -9.9999e-01 -9.9999e-01  6e-09  9e-17  9e-10
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -9.9999e-01 -2.0000e+00  1e+00  1e-15  1e+00
#  1: -9.9999e-01 -1.0100e+00  1e-02  6e-17  1e-02
#  2: -9.9999e-01 -1.0001e+00  1e-04  1e-16  1e-04
#  3: -9.9999e-01 -9.9999e-01  2e-06  9e-17  3e-06
#  4: -9.9999e-01 -9.9999e-01  2e-07  1e-16  1e-07
#  5: -9.9999e-01 -9.9999e-01  6e-09  1e-16  1e-09
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -9.9999e-01 -2.0000e+00  1e+00  9e-16  1e+00
#  1: -9.9999e-01 -1.0100e+00  1e-02  2e-16  1e-02
#  2: -9.9999e-01 -1.0001e+00  1e-04  7e-17  1e-04
#  3: -9.9999e-01 -9.9999e-01  2e-06  6e-17  3e-06
#  4: -9.9999e-01 -9.9999e-01  2e-07  6e-17  1e-07
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -9.9998e-01 -2.0000e+00  1e+00  1e-15  1e+00
#  1: -9.9998e-01 -1.0100e+00  1e-02  5e-17  1e-02
#  2: -9.9998e-01 -1.0001e+00  1e-04  8e-17  1e-04
#  3: -9.9998e-01 -9.9999e-01  2e-06  7e-17  3e-06
#  4: -9.9998e-01 -9.9998e-01  2e-07  9e-17  7e-08
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -9.9998e-01 -2.0000e+00  1e+00  0e+00  1e+00
#  1: -9.9998e-01 -1.0100e+00  1e-02  6e-17  1e-02
#  2: -9.9998e-01 -1.0001e+00  1e-04  2e-16  1e-04
#  3: -9.9998e-01 -9.9998e-01  3e-06  7e-17  3e-06
#  4: -9.9998e-01 -9.9998e-01  2e-07  1e-16  3e-08
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -9.9998e-01 -2.0000e+00  1e+00  0e+00  1e+00
#  1: -9.9998e-01 -1.0100e+00  1e-02  1e-16  1e-02
#  2: -9.9998e-01 -1.0001e+00  1e-04  7e-17  1e-04
#  3: -9.9998e-01 -9.9998e-01  3e-06  1e-16  3e-06
#  4: -9.9998e-01 -9.9998e-01  2e-07  6e-17  4e-17
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -9.9998e-01 -2.0000e+00  1e+00  2e-16  1e+00
#  1: -9.9998e-01 -1.0100e+00  1e-02  8e-17  1e-02
#  2: -9.9998e-01 -1.0001e+00  1e-04  1e-16  1e-04
#  3: -9.9998e-01 -9.9998e-01  3e-06  1e-16  3e-06
#  4: -9.9998e-01 -9.9998e-01  2e-07  7e-17  7e-17
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -9.9998e-01 -2.0000e+00  1e+00  1e-15  1e+00
#  1: -9.9998e-01 -1.0100e+00  1e-02  7e-17  1e-02
#  2: -9.9998e-01 -1.0001e+00  1e-04  9e-17  1e-04
#  3: -9.9998e-01 -9.9998e-01  3e-06  8e-17  4e-06
#  4: -9.9998e-01 -9.9998e-01  3e-07  1e-16  9e-17
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -9.9997e-01 -2.0000e+00  1e+00  0e+00  1e+00
#  1: -9.9997e-01 -1.0100e+00  1e-02  9e-17  1e-02
#  2: -9.9997e-01 -1.0001e+00  1e-04  2e-16  1e-04
#  3: -9.9997e-01 -9.9998e-01  3e-06  1e-16  4e-06
#  4: -9.9997e-01 -9.9997e-01  3e-07  8e-17  6e-17
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -9.9997e-01 -2.0000e+00  1e+00  1e-16  1e+00
#  1: -9.9997e-01 -1.0100e+00  1e-02  1e-16  1e-02
#  2: -9.9997e-01 -1.0001e+00  1e-04  1e-16  1e-04
#  3: -9.9997e-01 -9.9997e-01  3e-06  9e-17  4e-06
#  4: -9.9997e-01 -9.9997e-01  3e-07  3e-17  8e-17
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -9.9996e-01 -2.0000e+00  1e+00  8e-16  1e+00
#  1: -9.9996e-01 -1.0100e+00  1e-02  3e-17  1e-02
#  2: -9.9996e-01 -1.0001e+00  1e-04  8e-17  1e-04
#  3: -9.9996e-01 -9.9997e-01  4e-06  7e-17  4e-06
#  4: -9.9997e-01 -9.9997e-01  3e-07  6e-17  6e-17
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -9.9996e-01 -2.0000e+00  1e+00  0e+00  1e+00
#  1: -9.9996e-01 -1.0100e+00  1e-02  1e-16  1e-02
#  2: -9.9996e-01 -1.0001e+00  1e-04  6e-17  1e-04
#  3: -9.9996e-01 -9.9996e-01  4e-06  8e-17  5e-06
#  4: -9.9996e-01 -9.9996e-01  4e-07  8e-17  3e-17
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -9.9996e-01 -2.0000e+00  1e+00  4e-16  1e+00
#  1: -9.9996e-01 -1.0100e+00  1e-02  1e-16  1e-02
#  2: -9.9996e-01 -1.0001e+00  1e-04  5e-17  1e-04
#  3: -9.9996e-01 -9.9996e-01  4e-06  9e-17  5e-06
#  4: -9.9996e-01 -9.9996e-01  4e-07  0e+00  8e-17
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -9.9995e-01 -2.0000e+00  1e+00  9e-16  1e+00
#  1: -9.9995e-01 -1.0100e+00  1e-02  7e-17  1e-02
#  2: -9.9995e-01 -1.0001e+00  1e-04  2e-16  1e-04
#  3: -9.9995e-01 -9.9995e-01  5e-06  4e-17  5e-06
#  4: -9.9995e-01 -9.9995e-01  4e-07  6e-17  9e-17
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -9.9994e-01 -1.9999e+00  1e+00  1e-16  1e+00
#  1: -9.9994e-01 -1.0099e+00  1e-02  1e-16  1e-02
#  2: -9.9994e-01 -1.0000e+00  1e-04  6e-17  1e-04
#  3: -9.9994e-01 -9.9995e-01  5e-06  1e-16  6e-06
#  4: -9.9994e-01 -9.9995e-01  5e-07  2e-16  9e-17
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -9.9994e-01 -1.9999e+00  1e+00  2e-16  1e+00
#  1: -9.9994e-01 -1.0099e+00  1e-02  7e-17  1e-02
#  2: -9.9994e-01 -1.0000e+00  1e-04  7e-17  1e-04
#  3: -9.9994e-01 -9.9994e-01  5e-06  2e-16  6e-06
#  4: -9.9994e-01 -9.9994e-01  5e-07  1e-16  5e-17
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -9.9993e-01 -1.9999e+00  1e+00  4e-16  1e+00
#  1: -9.9993e-01 -1.0099e+00  1e-02  1e-16  1e-02
#  2: -9.9993e-01 -1.0000e+00  1e-04  2e-16  1e-04
#  3: -9.9993e-01 -9.9994e-01  6e-06  1e-16  7e-06
#  4: -9.9993e-01 -9.9993e-01  5e-07  7e-17  1e-16
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -9.9992e-01 -1.9999e+00  1e+00  0e+00  1e+00
#  1: -9.9992e-01 -1.0099e+00  1e-02  1e-16  1e-02
#  2: -9.9992e-01 -1.0000e+00  1e-04  1e-16  1e-04
#  3: -9.9992e-01 -9.9993e-01  6e-06  1e-16  7e-06
#  4: -9.9992e-01 -9.9992e-01  6e-07  1e-16  7e-17
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -9.9991e-01 -1.9999e+00  1e+00  7e-16  1e+00
#  1: -9.9991e-01 -1.0099e+00  1e-02  6e-17  1e-02
#  2: -9.9991e-01 -1.0000e+00  1e-04  5e-17  1e-04
#  3: -9.9991e-01 -9.9992e-01  7e-06  1e-16  8e-06
#  4: -9.9991e-01 -9.9991e-01  6e-07  6e-17  5e-17
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -9.9990e-01 -1.9999e+00  1e+00  2e-16  1e+00
#  1: -9.9990e-01 -1.0099e+00  1e-02  8e-17  1e-02
#  2: -9.9990e-01 -1.0000e+00  1e-04  7e-17  1e-04
#  3: -9.9990e-01 -9.9991e-01  7e-06  1e-16  8e-06
#  4: -9.9990e-01 -9.9990e-01  6e-07  7e-17  4e-17
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -9.9989e-01 -1.9999e+00  1e+00  1e-15  1e+00
#  1: -9.9989e-01 -1.0099e+00  1e-02  1e-16  1e-02
#  2: -9.9989e-01 -1.0000e+00  1e-04  6e-17  1e-04
#  3: -9.9989e-01 -9.9990e-01  8e-06  1e-16  9e-06
#  4: -9.9989e-01 -9.9989e-01  6e-07  2e-16  9e-17
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -9.9987e-01 -1.9999e+00  1e+00  1e-15  1e+00
#  1: -9.9987e-01 -1.0099e+00  1e-02  7e-17  1e-02
#  2: -9.9987e-01 -9.9999e-01  1e-04  1e-16  1e-04
#  3: -9.9988e-01 -9.9988e-01  8e-06  9e-17  9e-06
#  4: -9.9988e-01 -9.9988e-01  7e-07  1e-16  5e-17
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -9.9986e-01 -1.9999e+00  1e+00  4e-16  1e+00
#  1: -9.9986e-01 -1.0099e+00  1e-02  7e-17  1e-02
#  2: -9.9986e-01 -9.9997e-01  1e-04  5e-17  1e-04
#  3: -9.9986e-01 -9.9987e-01  9e-06  1e-16  1e-05
#  4: -9.9986e-01 -9.9986e-01  7e-07  8e-17  5e-17
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -9.9984e-01 -1.9999e+00  1e+00  7e-16  1e+00
#  1: -9.9984e-01 -1.0099e+00  1e-02  9e-17  1e-02
#  2: -9.9984e-01 -9.9996e-01  1e-04  9e-17  1e-04
#  3: -9.9984e-01 -9.9985e-01  9e-06  8e-17  1e-05
#  4: -9.9984e-01 -9.9985e-01  7e-07  2e-16  9e-17
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -9.9982e-01 -1.9998e+00  1e+00  6e-16  1e+00
#  1: -9.9982e-01 -1.0098e+00  1e-02  8e-17  1e-02
#  2: -9.9982e-01 -9.9994e-01  1e-04  6e-17  1e-04
#  3: -9.9982e-01 -9.9983e-01  1e-05  7e-17  1e-05
#  4: -9.9983e-01 -9.9983e-01  7e-07  1e-16  6e-17
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -9.9980e-01 -1.9998e+00  1e+00  7e-16  1e+00
#  1: -9.9980e-01 -1.0098e+00  1e-02  9e-17  1e-02
#  2: -9.9980e-01 -9.9992e-01  1e-04  1e-16  1e-04
#  3: -9.9980e-01 -9.9981e-01  1e-05  9e-17  1e-05
#  4: -9.9980e-01 -9.9981e-01  7e-07  7e-17  5e-17
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -9.9978e-01 -1.9998e+00  1e+00  7e-16  1e+00
#  1: -9.9978e-01 -1.0098e+00  1e-02  8e-17  1e-02
#  2: -9.9978e-01 -9.9990e-01  1e-04  6e-17  1e-04
#  3: -9.9978e-01 -9.9979e-01  1e-05  1e-16  1e-05
#  4: -9.9978e-01 -9.9978e-01  7e-07  9e-17  3e-17
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -9.9975e-01 -1.9998e+00  1e+00  2e-16  1e+00
#  1: -9.9975e-01 -1.0098e+00  1e-02  9e-17  1e-02
#  2: -9.9975e-01 -9.9987e-01  1e-04  8e-17  1e-04
#  3: -9.9975e-01 -9.9977e-01  1e-05  2e-16  1e-05
#  4: -9.9975e-01 -9.9975e-01  8e-07  2e-16  4e-17
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -9.9972e-01 -1.9997e+00  1e+00  0e+00  1e+00
#  1: -9.9972e-01 -1.0097e+00  1e-02  7e-17  1e-02
#  2: -9.9972e-01 -9.9985e-01  1e-04  9e-17  2e-04
#  3: -9.9972e-01 -9.9974e-01  1e-05  2e-16  1e-05
#  4: -9.9972e-01 -9.9972e-01  8e-07  2e-16  5e-17
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -9.9969e-01 -1.9997e+00  1e+00  1e-15  1e+00
#  1: -9.9969e-01 -1.0097e+00  1e-02  1e-16  1e-02
#  2: -9.9969e-01 -9.9982e-01  1e-04  1e-16  2e-04
#  3: -9.9969e-01 -9.9970e-01  1e-05  4e-17  1e-05
#  4: -9.9969e-01 -9.9969e-01  8e-07  8e-17  9e-17
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -9.9965e-01 -1.9997e+00  1e+00  0e+00  1e+00
#  1: -9.9965e-01 -1.0097e+00  1e-02  5e-17  1e-02
#  2: -9.9965e-01 -9.9978e-01  1e-04  6e-17  2e-04
#  3: -9.9965e-01 -9.9967e-01  1e-05  9e-17  2e-05
#  4: -9.9965e-01 -9.9965e-01  7e-07  9e-17  6e-17
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -9.9960e-01 -1.9996e+00  1e+00  2e-16  1e+00
#  1: -9.9960e-01 -1.0096e+00  1e-02  6e-17  1e-02
#  2: -9.9960e-01 -9.9974e-01  1e-04  1e-16  2e-04
#  3: -9.9961e-01 -9.9962e-01  2e-05  2e-16  2e-05
#  4: -9.9961e-01 -9.9961e-01  7e-07  7e-17  4e-17
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -9.9956e-01 -1.9996e+00  1e+00  4e-16  1e+00
#  1: -9.9956e-01 -1.0096e+00  1e-02  5e-17  1e-02
#  2: -9.9956e-01 -9.9970e-01  1e-04  2e-16  2e-04
#  3: -9.9956e-01 -9.9958e-01  2e-05  2e-16  2e-05
#  4: -9.9956e-01 -9.9956e-01  7e-07  4e-17  4e-17
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -9.9950e-01 -1.9995e+00  1e+00  4e-16  1e+00
#  1: -9.9950e-01 -1.0095e+00  1e-02  7e-17  1e-02
#  2: -9.9950e-01 -9.9965e-01  1e-04  4e-17  2e-04
#  3: -9.9951e-01 -9.9953e-01  2e-05  5e-17  2e-05
#  4: -9.9951e-01 -9.9951e-01  7e-07  6e-17  6e-17
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -9.9944e-01 -1.9995e+00  1e+00  1e-15  1e+00
#  1: -9.9944e-01 -1.0095e+00  1e-02  1e-16  1e-02
#  2: -9.9944e-01 -9.9959e-01  2e-04  8e-17  2e-04
#  3: -9.9945e-01 -9.9947e-01  2e-05  1e-16  2e-05
#  4: -9.9945e-01 -9.9945e-01  7e-07  2e-16  3e-17
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -9.9937e-01 -1.9994e+00  1e+00  7e-16  1e+00
#  1: -9.9937e-01 -1.0094e+00  1e-02  1e-16  1e-02
#  2: -9.9937e-01 -9.9953e-01  2e-04  9e-17  2e-04
#  3: -9.9938e-01 -9.9940e-01  2e-05  4e-17  2e-05
#  4: -9.9938e-01 -9.9938e-01  7e-07  1e-16  5e-17
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -9.9930e-01 -1.9994e+00  1e+00  4e-16  1e+00
#  1: -9.9930e-01 -1.0094e+00  1e-02  5e-17  1e-02
#  2: -9.9930e-01 -9.9946e-01  2e-04  1e-16  2e-04
#  3: -9.9931e-01 -9.9932e-01  2e-05  7e-17  2e-05
#  4: -9.9931e-01 -9.9931e-01  6e-07  3e-17  5e-17
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -9.9921e-01 -1.9993e+00  1e+00  4e-16  1e+00
#  1: -9.9921e-01 -1.0093e+00  1e-02  9e-17  1e-02
#  2: -9.9921e-01 -9.9938e-01  2e-04  1e-16  2e-04
#  3: -9.9922e-01 -9.9924e-01  2e-05  1e-16  2e-05
#  4: -9.9922e-01 -9.9922e-01  6e-07  8e-17  2e-08
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -9.9911e-01 -1.9992e+00  1e+00  9e-16  1e+00
#  1: -9.9911e-01 -1.0092e+00  1e-02  6e-17  1e-02
#  2: -9.9911e-01 -9.9930e-01  2e-04  1e-16  2e-04
#  3: -9.9913e-01 -9.9915e-01  2e-05  9e-17  2e-05
#  4: -9.9913e-01 -9.9913e-01  6e-07  1e-16  5e-08
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -9.9900e-01 -1.9991e+00  1e+00  0e+00  1e+00
#  1: -9.9900e-01 -1.0091e+00  1e-02  1e-16  1e-02
#  2: -9.9901e-01 -9.9920e-01  2e-04  7e-17  2e-04
#  3: -9.9902e-01 -9.9904e-01  2e-05  1e-16  1e-05
#  4: -9.9902e-01 -9.9902e-01  6e-07  1e-16  8e-08
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -9.9888e-01 -1.9990e+00  1e+00  4e-16  1e+00
#  1: -9.9888e-01 -1.0090e+00  1e-02  2e-16  1e-02
#  2: -9.9889e-01 -9.9909e-01  2e-04  1e-16  2e-04
#  3: -9.9890e-01 -9.9892e-01  2e-05  1e-16  1e-05
#  4: -9.9890e-01 -9.9890e-01  6e-07  9e-17  9e-08
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -9.9875e-01 -1.9989e+00  1e+00  0e+00  1e+00
#  1: -9.9875e-01 -1.0089e+00  1e-02  2e-16  1e-02
#  2: -9.9875e-01 -9.9896e-01  2e-04  2e-16  3e-04
#  3: -9.9877e-01 -9.9879e-01  2e-05  3e-17  1e-05
#  4: -9.9877e-01 -9.9877e-01  6e-07  1e-16  1e-07
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -9.9859e-01 -1.9987e+00  1e+00  1e-15  1e+00
#  1: -9.9859e-01 -1.0087e+00  1e-02  8e-17  1e-02
#  2: -9.9860e-01 -9.9882e-01  2e-04  8e-17  3e-04
#  3: -9.9862e-01 -9.9864e-01  2e-05  1e-16  1e-05
#  4: -9.9862e-01 -9.9862e-01  6e-07  8e-17  9e-08
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -9.9842e-01 -1.9986e+00  1e+00  3e-16  1e+00
#  1: -9.9842e-01 -1.0086e+00  1e-02  1e-16  1e-02
#  2: -9.9843e-01 -9.9866e-01  2e-04  7e-17  3e-04
#  3: -9.9845e-01 -9.9847e-01  2e-05  1e-16  7e-06
#  4: -9.9845e-01 -9.9845e-01  6e-07  1e-16  7e-08
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -9.9823e-01 -1.9984e+00  1e+00  0e+00  1e+00
#  1: -9.9823e-01 -1.0084e+00  1e-02  7e-17  1e-02
#  2: -9.9823e-01 -9.9849e-01  3e-04  5e-17  3e-04
#  3: -9.9826e-01 -9.9828e-01  2e-05  9e-17  3e-06
#  4: -9.9826e-01 -9.9826e-01  5e-07  1e-16  4e-08
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -9.9801e-01 -1.9982e+00  1e+00  4e-16  1e+00
#  1: -9.9801e-01 -1.0082e+00  1e-02  7e-17  1e-02
#  2: -9.9802e-01 -9.9829e-01  3e-04  4e-17  3e-04
#  3: -9.9804e-01 -9.9807e-01  2e-05  6e-17  6e-17
#  4: -9.9805e-01 -9.9805e-01  5e-07  8e-17  7e-17
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -9.9777e-01 -1.9980e+00  1e+00  4e-16  1e+00
#  1: -9.9777e-01 -1.0080e+00  1e-02  7e-17  1e-02
#  2: -9.9778e-01 -9.9806e-01  3e-04  6e-17  3e-04
#  3: -9.9781e-01 -9.9783e-01  2e-05  1e-16  5e-17
#  4: -9.9781e-01 -9.9781e-01  5e-07  2e-16  6e-17
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -9.9750e-01 -1.9977e+00  1e+00  0e+00  1e+00
#  1: -9.9750e-01 -1.0077e+00  1e-02  5e-17  1e-02
#  2: -9.9751e-01 -9.9781e-01  3e-04  9e-17  4e-04
#  3: -9.9754e-01 -9.9757e-01  3e-05  1e-16  9e-17
#  4: -9.9754e-01 -9.9754e-01  6e-07  8e-17  8e-17
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -9.9720e-01 -1.9975e+00  1e+00  2e-16  1e+00
#  1: -9.9720e-01 -1.0075e+00  1e-02  6e-17  1e-02
#  2: -9.9720e-01 -9.9753e-01  3e-04  7e-17  4e-04
#  3: -9.9724e-01 -9.9727e-01  3e-05  1e-16  4e-17
#  4: -9.9724e-01 -9.9724e-01  6e-07  9e-17  7e-17
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -9.9685e-01 -1.9972e+00  1e+00  0e+00  1e+00
#  1: -9.9685e-01 -1.0072e+00  1e-02  5e-17  1e-02
#  2: -9.9686e-01 -9.9721e-01  3e-04  7e-17  4e-04
#  3: -9.9690e-01 -9.9693e-01  3e-05  3e-17  7e-17
#  4: -9.9690e-01 -9.9690e-01  6e-07  8e-17  9e-17
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -9.9647e-01 -1.9968e+00  1e+00  9e-16  1e+00
#  1: -9.9647e-01 -1.0068e+00  1e-02  1e-16  1e-02
#  2: -9.9648e-01 -9.9685e-01  4e-04  1e-16  4e-04
#  3: -9.9652e-01 -9.9656e-01  3e-05  6e-17  1e-16
#  4: -9.9652e-01 -9.9653e-01  6e-07  6e-17  9e-17
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -9.9604e-01 -1.9964e+00  1e+00  2e-16  1e+00
#  1: -9.9604e-01 -1.0064e+00  1e-02  1e-16  1e-02
#  2: -9.9606e-01 -9.9645e-01  4e-04  3e-17  5e-04
#  3: -9.9610e-01 -9.9614e-01  4e-05  8e-17  8e-17
#  4: -9.9610e-01 -9.9610e-01  7e-07  2e-16  7e-17
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -9.9556e-01 -1.9960e+00  1e+00  4e-16  1e+00
#  1: -9.9556e-01 -1.0060e+00  1e-02  7e-17  1e-02
#  2: -9.9558e-01 -9.9600e-01  4e-04  5e-17  5e-04
#  3: -9.9562e-01 -9.9566e-01  4e-05  7e-17  5e-17
#  4: -9.9562e-01 -9.9563e-01  7e-07  8e-17  8e-17
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -9.9501e-01 -1.9955e+00  1e+00  2e-16  1e+00
#  1: -9.9501e-01 -1.0055e+00  1e-02  9e-17  1e-02
#  2: -9.9504e-01 -9.9549e-01  5e-04  8e-17  5e-04
#  3: -9.9509e-01 -9.9513e-01  4e-05  7e-17  6e-17
#  4: -9.9509e-01 -9.9509e-01  7e-07  8e-17  6e-17
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -9.9441e-01 -1.9949e+00  1e+00  1e-16  1e+00
#  1: -9.9441e-01 -1.0049e+00  1e-02  1e-16  1e-02
#  2: -9.9444e-01 -9.9492e-01  5e-04  2e-16  6e-04
#  3: -9.9449e-01 -9.9454e-01  5e-05  1e-16  8e-17
#  4: -9.9449e-01 -9.9449e-01  8e-07  1e-16  9e-17
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -9.9372e-01 -1.9943e+00  1e+00  2e-16  1e+00
#  1: -9.9372e-01 -1.0043e+00  1e-02  2e-16  1e-02
#  2: -9.9376e-01 -9.9428e-01  5e-04  7e-17  6e-04
#  3: -9.9382e-01 -9.9387e-01  5e-05  1e-16  5e-17
#  4: -9.9382e-01 -9.9382e-01  8e-07  3e-17  7e-17
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -9.9296e-01 -1.9936e+00  1e+00  7e-16  1e+00
#  1: -9.9296e-01 -1.0036e+00  1e-02  7e-17  1e-02
#  2: -9.9300e-01 -9.9356e-01  6e-04  7e-17  7e-04
#  3: -9.9306e-01 -9.9312e-01  5e-05  9e-17  5e-17
#  4: -9.9307e-01 -9.9307e-01  8e-07  7e-17  6e-17
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -9.9210e-01 -1.9929e+00  1e+00  9e-16  1e+00
#  1: -9.9210e-01 -1.0029e+00  1e-02  2e-16  1e-02
#  2: -9.9215e-01 -9.9276e-01  6e-04  1e-16  7e-04
#  3: -9.9222e-01 -9.9227e-01  6e-05  4e-17  6e-17
#  4: -9.9222e-01 -9.9222e-01  8e-07  2e-16  7e-17
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -9.9113e-01 -1.9920e+00  1e+00  0e+00  1e+00
#  1: -9.9114e-01 -1.0020e+00  1e-02  7e-17  1e-02
#  2: -9.9120e-01 -9.9185e-01  7e-04  4e-17  8e-04
#  3: -9.9127e-01 -9.9133e-01  6e-05  1e-16  7e-17
#  4: -9.9127e-01 -9.9127e-01  8e-07  8e-17  8e-17
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -9.9005e-01 -1.9910e+00  1e+00  0e+00  1e+00
#  1: -9.9005e-01 -1.0010e+00  1e-02  7e-17  1e-02
#  2: -9.9013e-01 -9.9083e-01  7e-04  2e-16  8e-04
#  3: -9.9020e-01 -9.9026e-01  6e-05  1e-16  6e-17
#  4: -9.9021e-01 -9.9021e-01  9e-07  8e-17  6e-17
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -9.8884e-01 -1.9899e+00  1e+00  2e-16  1e+00
#  1: -9.8884e-01 -9.9990e-01  1e-02  7e-17  1e-02
#  2: -9.8893e-01 -9.8969e-01  8e-04  1e-16  9e-04
#  3: -9.8901e-01 -9.8907e-01  6e-05  1e-16  7e-17
#  4: -9.8901e-01 -9.8901e-01  9e-07  4e-17  6e-17
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -9.8748e-01 -1.9887e+00  1e+00  0e+00  1e+00
#  1: -9.8748e-01 -9.9866e-01  1e-02  9e-17  1e-02
#  2: -9.8758e-01 -9.8840e-01  8e-04  5e-17  9e-04
#  3: -9.8767e-01 -9.8773e-01  6e-05  9e-17  5e-17
#  4: -9.8767e-01 -9.8767e-01  9e-07  2e-16  4e-17
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -9.8595e-01 -1.9873e+00  1e+00  1e-15  1e+00
#  1: -9.8595e-01 -9.9728e-01  1e-02  1e-16  1e-02
#  2: -9.8607e-01 -9.8695e-01  9e-04  1e-16  1e-03
#  3: -9.8616e-01 -9.8623e-01  7e-05  6e-17  9e-17
#  4: -9.8616e-01 -9.8617e-01  9e-07  8e-17  5e-17
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -9.8424e-01 -1.9857e+00  1e+00  1e-15  1e+00
#  1: -9.8424e-01 -9.9572e-01  1e-02  1e-16  1e-02
#  2: -9.8438e-01 -9.8532e-01  9e-04  7e-17  1e-03
#  3: -9.8448e-01 -9.8454e-01  7e-05  1e-16  5e-17
#  4: -9.8448e-01 -9.8448e-01  9e-07  1e-16  8e-17
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -9.8232e-01 -1.9840e+00  1e+00  2e-16  1e+00
#  1: -9.8232e-01 -9.9397e-01  1e-02  1e-16  1e-02
#  2: -9.8249e-01 -9.8349e-01  1e-03  6e-17  1e-03
#  3: -9.8258e-01 -9.8265e-01  7e-05  8e-17  5e-17
#  4: -9.8258e-01 -9.8258e-01  9e-07  6e-17  5e-17
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -9.8016e-01 -1.9820e+00  1e+00  9e-16  1e+00
#  1: -9.8016e-01 -9.9201e-01  1e-02  7e-17  1e-02
#  2: -9.8036e-01 -9.8142e-01  1e-03  7e-17  1e-03
#  3: -9.8046e-01 -9.8053e-01  7e-05  9e-17  5e-17
#  4: -9.8046e-01 -9.8046e-01  8e-07  1e-16  7e-17
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -9.7774e-01 -1.9798e+00  1e+00  9e-16  1e+00
#  1: -9.7775e-01 -9.8980e-01  1e-02  4e-17  1e-02
#  2: -9.7797e-01 -9.7911e-01  1e-03  5e-17  1e-03
#  3: -9.7807e-01 -9.7814e-01  7e-05  9e-17  1e-16
#  4: -9.7807e-01 -9.7807e-01  8e-07  8e-17  4e-17
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -9.7503e-01 -1.9774e+00  1e+00  4e-16  1e+00
#  1: -9.7503e-01 -9.8732e-01  1e-02  9e-17  1e-02
#  2: -9.7529e-01 -9.7650e-01  1e-03  7e-17  1e-03
#  3: -9.7540e-01 -9.7547e-01  7e-05  1e-16  9e-17
#  4: -9.7540e-01 -9.7540e-01  8e-07  6e-17  6e-17
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -9.7198e-01 -1.9746e+00  1e+00  3e-16  1e+00
#  1: -9.7199e-01 -9.8454e-01  1e-02  8e-17  2e-02
#  2: -9.7229e-01 -9.7357e-01  1e-03  7e-17  1e-03
#  3: -9.7239e-01 -9.7246e-01  7e-05  2e-16  6e-17
#  4: -9.7239e-01 -9.7240e-01  8e-07  7e-17  6e-17
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -9.6857e-01 -1.9715e+00  1e+00  0e+00  1e+00
#  1: -9.6858e-01 -9.8141e-01  1e-02  1e-16  2e-02
#  2: -9.6892e-01 -9.7027e-01  1e-03  5e-17  1e-03
#  3: -9.6903e-01 -9.6909e-01  7e-05  1e-16  5e-17
#  4: -9.6903e-01 -9.6903e-01  8e-07  6e-17  4e-17
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -9.6473e-01 -1.9680e+00  1e+00  1e-16  1e+00
#  1: -9.6475e-01 -9.7790e-01  1e-02  5e-17  2e-02
#  2: -9.6514e-01 -9.6656e-01  1e-03  7e-17  1e-03
#  3: -9.6525e-01 -9.6531e-01  7e-05  8e-17  1e-16
#  4: -9.6525e-01 -9.6525e-01  7e-07  6e-17  1e-16
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -9.6044e-01 -1.9640e+00  1e+00  1e-16  1e+00
#  1: -9.6046e-01 -9.7395e-01  1e-02  1e-16  2e-02
#  2: -9.6090e-01 -9.6239e-01  1e-03  1e-16  2e-03
#  3: -9.6101e-01 -9.6107e-01  7e-05  7e-17  7e-17
#  4: -9.6101e-01 -9.6101e-01  7e-07  7e-17  4e-17
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -9.5562e-01 -1.9596e+00  1e+00  2e-16  1e+00
#  1: -9.5564e-01 -9.6951e-01  1e-02  1e-16  2e-02
#  2: -9.5614e-01 -9.5770e-01  2e-03  3e-17  2e-03
#  3: -9.5625e-01 -9.5631e-01  6e-05  1e-16  8e-17
#  4: -9.5625e-01 -9.5625e-01  7e-07  1e-16  4e-17
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -9.5021e-01 -1.9547e+00  1e+00  1e-16  1e+00
#  1: -9.5024e-01 -9.6452e-01  1e-02  1e-16  2e-02
#  2: -9.5080e-01 -9.5242e-01  2e-03  7e-17  2e-03
#  3: -9.5091e-01 -9.5097e-01  6e-05  9e-17  9e-17
#  4: -9.5091e-01 -9.5091e-01  6e-07  9e-17  6e-17
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -9.4414e-01 -1.9491e+00  1e+00  4e-16  1e+00
#  1: -9.4418e-01 -9.5892e-01  1e-02  7e-17  2e-02
#  2: -9.4481e-01 -9.4649e-01  2e-03  8e-17  2e-03
#  3: -9.4492e-01 -9.4498e-01  6e-05  6e-17  8e-17
#  4: -9.4492e-01 -9.4492e-01  6e-07  1e-16  4e-17
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -9.3734e-01 -1.9428e+00  1e+00  1e-16  1e+00
#  1: -9.3739e-01 -9.5261e-01  2e-02  7e-17  2e-02
#  2: -9.3809e-01 -9.3983e-01  2e-03  2e-16  2e-03
#  3: -9.3820e-01 -9.3825e-01  5e-05  2e-16  4e-17
#  4: -9.3820e-01 -9.3820e-01  6e-07  9e-17  6e-17
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -9.2971e-01 -1.9358e+00  1e+00  1e-16  1e+00
#  1: -9.2977e-01 -9.4552e-01  2e-02  6e-17  2e-02
#  2: -9.3056e-01 -9.3233e-01  2e-03  7e-17  2e-03
#  3: -9.3066e-01 -9.3071e-01  5e-05  1e-16  9e-07
#  4: -9.3066e-01 -9.3066e-01  5e-07  2e-16  9e-09
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -9.2115e-01 -1.9279e+00  1e+00  4e-16  1e+00
#  1: -9.2122e-01 -9.3754e-01  2e-02  1e-16  2e-02
#  2: -9.2210e-01 -9.2391e-01  2e-03  2e-16  1e-03
#  3: -9.2220e-01 -9.2225e-01  5e-05  1e-16  4e-06
#  4: -9.2220e-01 -9.2220e-01  5e-07  1e-16  4e-08
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -9.1155e-01 -1.9189e+00  1e+00  0e+00  1e+00
#  1: -9.1164e-01 -9.2857e-01  2e-02  6e-17  2e-02
#  2: -9.1261e-01 -9.1444e-01  2e-03  2e-16  1e-03
#  3: -9.1270e-01 -9.1275e-01  5e-05  1e-16  6e-06
#  4: -9.1270e-01 -9.1271e-01  5e-07  9e-17  6e-08
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -9.0079e-01 -1.9089e+00  1e+00  2e-16  1e+00
#  1: -9.0089e-01 -9.1847e-01  2e-02  7e-17  2e-02
#  2: -9.0196e-01 -9.0380e-01  2e-03  1e-16  1e-03
#  3: -9.0205e-01 -9.0210e-01  5e-05  1e-16  8e-06
#  4: -9.0205e-01 -9.0205e-01  5e-07  1e-16  8e-08
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -8.8872e-01 -1.8977e+00  1e+00  0e+00  1e+00
#  1: -8.8884e-01 -9.0710e-01  2e-02  7e-17  2e-02
#  2: -8.9002e-01 -8.9185e-01  2e-03  9e-17  1e-03
#  3: -8.9010e-01 -8.9015e-01  4e-05  2e-16  9e-06
#  4: -8.9010e-01 -8.9010e-01  4e-07  1e-16  9e-08
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -8.7518e-01 -1.8850e+00  1e+00  2e-16  1e+00
#  1: -8.7533e-01 -8.9431e-01  2e-02  1e-16  2e-02
#  2: -8.7662e-01 -8.7842e-01  2e-03  7e-17  1e-03
#  3: -8.7669e-01 -8.7673e-01  4e-05  9e-17  8e-06
#  4: -8.7669e-01 -8.7669e-01  4e-07  7e-17  8e-08
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -8.6000e-01 -1.8708e+00  1e+00  0e+00  1e+00
#  1: -8.6018e-01 -8.7998e-01  2e-02  1e-16  2e-02
#  2: -8.6158e-01 -8.6334e-01  2e-03  9e-17  8e-04
#  3: -8.6165e-01 -8.6168e-01  4e-05  7e-17  7e-06
#  4: -8.6165e-01 -8.6165e-01  4e-07  1e-16  7e-08
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -8.4297e-01 -1.8547e+00  1e+00  2e-16  1e+00
#  1: -8.4319e-01 -8.6396e-01  2e-02  9e-17  2e-02
#  2: -8.4470e-01 -8.4642e-01  2e-03  6e-17  6e-04
#  3: -8.4476e-01 -8.4480e-01  4e-05  2e-16  6e-06
#  4: -8.4476e-01 -8.4476e-01  4e-07  2e-16  6e-08
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -8.2388e-01 -1.8367e+00  1e+00  0e+00  1e+00
#  1: -8.2415e-01 -8.4594e-01  2e-02  4e-17  3e-02
#  2: -8.2577e-01 -8.2743e-01  2e-03  8e-17  4e-04
#  3: -8.2582e-01 -8.2585e-01  3e-05  1e-16  4e-06
#  4: -8.2582e-01 -8.2582e-01  3e-07  1e-16  4e-08
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -8.0248e-01 -1.8164e+00  1e+00  0e+00  1e+00
#  1: -8.0279e-01 -8.2568e-01  2e-02  1e-16  3e-02
#  2: -8.0452e-01 -8.0611e-01  2e-03  7e-17  1e-04
#  3: -8.0457e-01 -8.0460e-01  3e-05  1e-16  2e-06
#  4: -8.0457e-01 -8.0457e-01  3e-07  7e-17  2e-08
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -7.7847e-01 -1.7937e+00  1e+00  1e-16  1e+00
#  1: -7.7884e-01 -8.0289e-01  2e-02  1e-16  3e-02
#  2: -7.8068e-01 -7.8225e-01  2e-03  2e-16  7e-17
#  3: -7.8072e-01 -7.8075e-01  3e-05  2e-16  1e-16
#  4: -7.8072e-01 -7.8072e-01  3e-07  2e-16  1e-16
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -7.5156e-01 -1.7683e+00  1e+00  1e-16  1e+00
#  1: -7.5199e-01 -7.7727e-01  3e-02  5e-17  3e-02
#  2: -7.5393e-01 -7.5557e-01  2e-03  1e-16  5e-17
#  3: -7.5397e-01 -7.5399e-01  3e-05  2e-16  7e-17
#  4: -7.5397e-01 -7.5397e-01  3e-07  1e-16  1e-16
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -7.2137e-01 -1.7397e+00  1e+00  0e+00  1e+00
#  1: -7.2188e-01 -7.4845e-01  3e-02  2e-16  3e-02
#  2: -7.2391e-01 -7.2562e-01  2e-03  4e-17  7e-17
#  3: -7.2395e-01 -7.2397e-01  3e-05  8e-17  3e-17
#  4: -7.2395e-01 -7.2395e-01  3e-07  9e-17  7e-17
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -6.8753e-01 -1.7075e+00  1e+00  0e+00  1e+00
#  1: -6.8812e-01 -7.1604e-01  3e-02  6e-17  3e-02
#  2: -6.9023e-01 -6.9199e-01  2e-03  8e-17  3e-17
#  3: -6.9026e-01 -6.9029e-01  3e-05  2e-16  8e-17
#  4: -6.9026e-01 -6.9026e-01  3e-07  8e-17  6e-17
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -6.4958e-01 -1.6714e+00  1e+00  0e+00  1e+00
#  1: -6.5026e-01 -6.7957e-01  3e-02  4e-17  4e-02
#  2: -6.5244e-01 -6.5423e-01  2e-03  1e-16  6e-17
#  3: -6.5247e-01 -6.5250e-01  2e-05  8e-17  6e-17
#  4: -6.5247e-01 -6.5247e-01  2e-07  8e-17  1e-16
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -6.0702e-01 -1.6307e+00  1e+00  0e+00  1e+00
#  1: -6.0780e-01 -6.3853e-01  3e-02  2e-16  4e-02
#  2: -6.1004e-01 -6.1184e-01  2e-03  1e-16  7e-17
#  3: -6.1007e-01 -6.1009e-01  2e-05  6e-17  7e-17
#  4: -6.1007e-01 -6.1007e-01  2e-07  7e-17  8e-17
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -5.5930e-01 -1.5850e+00  1e+00  1e-16  1e+00
#  1: -5.6018e-01 -5.9236e-01  3e-02  9e-17  4e-02
#  2: -5.6246e-01 -5.6426e-01  2e-03  9e-17  6e-17
#  3: -5.6249e-01 -5.6251e-01  2e-05  6e-17  5e-17
#  4: -5.6249e-01 -5.6249e-01  2e-07  7e-17  7e-17
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -5.0578e-01 -1.5336e+00  1e+00  1e-16  1e+00
#  1: -5.0678e-01 -5.4041e-01  3e-02  5e-17  4e-02
#  2: -5.0908e-01 -5.1085e-01  2e-03  2e-16  1e-16
#  3: -5.0910e-01 -5.0912e-01  2e-05  6e-17  1e-16
#  4: -5.0910e-01 -5.0910e-01  2e-07  1e-16  9e-17
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -4.4576e-01 -1.4758e+00  1e+00  0e+00  1e+00
#  1: -4.4688e-01 -4.8195e-01  4e-02  8e-17  4e-02
#  2: -4.4918e-01 -4.5091e-01  2e-03  3e-17  2e-16
#  3: -4.4920e-01 -4.4922e-01  2e-05  1e-16  5e-17
#  4: -4.4920e-01 -4.4920e-01  2e-07  6e-17  8e-17
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -3.7845e-01 -1.4107e+00  1e+00  2e-16  1e+00
#  1: -3.7969e-01 -4.1617e-01  4e-02  8e-17  4e-02
#  2: -3.8198e-01 -3.8371e-01  2e-03  8e-17  9e-05
#  3: -3.8200e-01 -3.8202e-01  2e-05  5e-17  9e-07
#  4: -3.8200e-01 -3.8200e-01  2e-07  8e-17  9e-09
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -3.0295e-01 -1.3376e+00  1e+00  0e+00  1e+00
#  1: -3.0433e-01 -3.4214e-01  4e-02  7e-17  4e-02
#  2: -3.0657e-01 -3.0829e-01  2e-03  6e-17  2e-04
#  3: -3.0659e-01 -3.0661e-01  2e-05  6e-17  2e-06
#  4: -3.0659e-01 -3.0659e-01  2e-07  1e-16  2e-08
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -2.1827e-01 -1.2553e+00  1e+00  2e-16  1e+00
#  1: -2.1978e-01 -2.5886e-01  4e-02  1e-16  5e-02
#  2: -2.2197e-01 -2.2365e-01  2e-03  1e-16  3e-04
#  3: -2.2198e-01 -2.2200e-01  2e-05  6e-17  3e-06
#  4: -2.2198e-01 -2.2198e-01  2e-07  8e-17  3e-08
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -1.2329e-01 -1.1627e+00  1e+00  0e+00  1e+00
#  1: -1.2493e-01 -1.6515e-01  4e-02  6e-17  5e-02
#  2: -1.2704e-01 -1.2867e-01  2e-03  1e-17  4e-04
#  3: -1.2705e-01 -1.2706e-01  2e-05  9e-17  4e-06
#  4: -1.2705e-01 -1.2705e-01  2e-07  7e-17  4e-08
#  5: -1.2705e-01 -1.2705e-01  2e-09  1e-16  4e-10
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -1.6746e-02 -1.0587e+00  1e+00  1e-16  1e+00
#  1: -1.8516e-02 -5.9748e-02  4e-02  1e-16  5e-02
#  2: -2.0521e-02 -2.2083e-02  2e-03  2e-16  4e-04
#  3: -2.0530e-02 -2.0546e-02  2e-05  2e-16  4e-06
#  4: -2.0530e-02 -2.0530e-02  2e-07  7e-17  4e-08
#  5: -2.0530e-02 -2.0530e-02  2e-09  6e-17  4e-10
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -9.9989e-01 -1.9999e+00  1e+00  1e-15  1e+00
#  1: -9.9989e-01 -1.0099e+00  1e-02  1e-16  1e-02
#  2: -9.9989e-01 -1.0000e+00  1e-04  6e-17  1e-04
#  3: -9.9989e-01 -9.9990e-01  8e-06  8e-17  9e-06
#  4: -9.9989e-01 -9.9989e-01  6e-07  3e-17  9e-17
# Optimal solution found.
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:8: RankWarning: Polyfit may be poorly conditioned

# %%
portfolios
# Out:
#                 MVP       IVP       HRP
# Apple      0.260790  0.202113  0.243984
# Amazon     0.134563  0.175866  0.222179
# Alphabet   0.311311  0.233598  0.164062
# Microsoft  0.171536  0.215568  0.151398
# Facebook   0.121800  0.172856  0.218377
